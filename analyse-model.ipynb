# %%
import calliope

# %%
model = calliope.Model('balancing-act-model/national/model.yaml')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model = calliope.Model('balancing-act-model/national/model.yaml')
#
# File ~/miniconda3/envs/calliope/lib/python3.9/site-packages/calliope/core/model.py:78, in Model.__init__(self, config, model_data, *args, **kwargs)
#      76 log_time(logger, self._timings, "model_creation", comment="Model: initialising")
#      77 if isinstance(config, str):
# ---> 78     model_run, debug_data = model_run_from_yaml(config, *args, **kwargs)
#      79     self._init_from_model_run(model_run, debug_data)
#      80 elif isinstance(config, dict):
#
# File ~/miniconda3/envs/calliope/lib/python3.9/site-packages/calliope/preprocess/model_run.py:73, in model_run_from_yaml(model_file, timeseries_dataframes, scenario, override_dict)
#      67 config.config_path = model_file
# ...
